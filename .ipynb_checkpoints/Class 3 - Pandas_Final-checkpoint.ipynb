# %% [markdown]
# ## Hi, I am Panda! Hope you are doing great!
# ![Panda](img/panda.jpg)
#
# #### Fun apart, what we are going to look at not this panda but pandas which help us a lot in data crunching!
# ![Pandas](img/pandas.png)
#
# ## Let's see why we need Pandas?
# * Fast and efficient DataFrame object for data manipulation
# * Reading and writing data between in-memory data structures and different formats: CSV and text files, Microsoft Excel, SQL databases, and the fast HDF5 format;
# * Intelligent data alignment and integrated handling of missing data
# * Intelligent label-based slicing, fancy indexing, and subsetting of large data sets;
# * Columns can be inserted and deleted
# * Aggregating or transforming data with a powerful group by engine allowing split-apply-combine operations on data sets;
# * High performance merging and joining of data sets;
# * Hierarchical axis indexing provides an intuitive way of working with high-dimensional data in a lower-dimensional data structure;
# * Time series-functionality

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## What are Series?
# * It is an array
# * It is one-dimensional
# * Can store data of any type (Integer, Float, String, Dates etc.)
# * Has indexes referring to the axis labels

# %%
arr = np.array([1,2,3,4,5])
type(arr)
# Out:
# numpy.ndarray

# %%
ser1 = pd.Series(arr)
type(ser1)
# index = np.arange(len(arr))
# select * from sometable where someid = something
# Out:
# pandas.core.series.Series

# %%
#ser2 = pd.Series(data=[11,12,13,14],index=np.arange(1,10,2))
#ser2

# %%
df1 = pd.DataFrame({'col1':ser1,'col2':ser2})
df1
# Out:
#    col1  col2
# 0     1  11.0
# 1     2  12.0
# 2     3  13.0
# 3     4  14.0
# 4     5   NaN

# %%
team_data = pd.read_csv('data/team.csv')
team_data
# Out:
#                      team_name         team_captain
# 0          Chennai Super Kings             MS Dhoni
# 1  Royal Challengers Bangalore          Virat Kohli
# 2        Kolkata Knight Riders       Dinesh Karthik
# 3             Rajasthan Royals       Ajinkya Rahane
# 4          Sunrisers Hyderabad      Kane Williamson
# 5              Kings XI Punjab  Ravichandran Ashwin
# 6               Mumbai Indians         Rohit Sharma
# 7             Delhi Daredevils         Shreyas Iyer

# %%
player_data = pd.read_csv('data/iplfinal.csv',sep='|')
#player_data
#player_data.head()
player_data.tail()
# Out:
#                                      match_description  match_date  \
# 958  Chennai Super Kings vs Sunrisers Hyderabad, Fi...  2018-05-27
# 959  Chennai Super Kings vs Sunrisers Hyderabad, Fi...  2018-05-27
# 960  Chennai Super Kings vs Sunrisers Hyderabad, Fi...  2018-05-27
# 961  Chennai Super Kings vs Sunrisers Hyderabad, Fi...  2018-05-27
# 962  Chennai Super Kings vs Sunrisers Hyderabad, Fi...  2018-05-27
#
#            match_venue match_location                       match_result  \
# 958  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 8 wkts
# 959  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 8 wkts
# 960  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 8 wkts
# 961  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 8 wkts
# 962  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 8 wkts
#
#                        team_name innings_order       batsman_name  \
# 958  Sunrisers Hyderabad Innings     innings_1  Carlos Brathwaite
# 959  Chennai Super Kings Innings     innings_2       Shane Watson
# 960  Chennai Super Kings Innings     innings_2     Faf du Plessis
# 961  Chennai Super Kings Innings     innings_2       Suresh Raina
# 962  Chennai Super Kings Innings     innings_2      Ambati Rayudu
#
#                dismissal_mode  runs  balls  fours  sixes
# 958      c Rayudu b SN Thakur    21     11      0      3
# 959                   not out   117     57      1      8
# 960      c & b Sandeep Sharma    10     11      1      0
# 961  c Goswami b C Brathwaite    32     24      3      1
# 962                   not out    16     19      1      1

# %%
player_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 963 entries, 0 to 962
# Data columns (total 13 columns):
# match_description    963 non-null object
# match_date           963 non-null object
# match_venue          963 non-null object
# match_location       963 non-null object
# match_result         963 non-null object
# team_name            963 non-null object
# innings_order        963 non-null object
# batsman_name         963 non-null object
# dismissal_mode       963 non-null object
# runs                 963 non-null int64
# balls                963 non-null int64
# fours                963 non-null int64
# sixes                963 non-null int64
# dtypes: int64(4), object(9)
# memory usage: 97.9+ KB

# %%
player_data.describe()
# Out:
#              runs       balls       fours       sixes
# count  963.000000  963.000000  963.000000  963.000000
# mean    20.516096   14.865005    1.665628    0.937695
# std     21.900609   13.289220    1.990187    1.559046
# min      0.000000    0.000000    0.000000    0.000000
# 25%      4.000000    5.000000    0.000000    0.000000
# 50%     13.000000   11.000000    1.000000    0.000000
# 75%     31.500000   22.000000    3.000000    1.000000
# max    128.000000   70.000000    9.000000   11.000000

# %%
# let's see what all information we can fetch from a series
ser3 = player_data.balls
ser3
#ser3.describe()
# type(ser3)
#ser3.size
#ser3.axes
#ser3.ndim
#type(ser3.values)
#ser3.empty
# Out:
# 0      18
# 1       2
# 2      29
# 3      29
# 4      20
# 5      22
# 6      14
# 7      19
# 8       6
# 9      22
# 10      5
# 11     13
# 12     30
# 13      1
# 14      5
# 15      3
# 16      2
# 17      6
# 18     42
# 19     11
# 20     13
# 21     13
# 22      7
# 23     16
# 24     13
# 25     16
# 26      5
# 27     22
# 28     33
# 29     23
#        ..
# 933    24
# 934     3
# 935    24
# 936    19
# 937     7
# 938     4
# 939    10
# 940     2
# 941    31
# 942    13
# 943    16
# 944     8
# 945     6
# 946    20
# 947     7
# 948    12
# 949     4
# 950     3
# 951     0
# 952     5
# 953    25
# 954    36
# 955    15
# 956    25
# 957     4
# 958    11
# 959    57
# 960    11
# 961    24
# 962    19
# Name: balls, Length: 963, dtype: int64

# %%
player_data.match_venue
# Out:
# 0                                  Wankhede Stadium,
# 1                                  Wankhede Stadium,
# 2                                  Wankhede Stadium,
# 3                                  Wankhede Stadium,
# 4                                  Wankhede Stadium,
# 5                                  Wankhede Stadium,
# 6                                  Wankhede Stadium,
# 7                                  Wankhede Stadium,
# 8                                  Wankhede Stadium,
# 9                                  Wankhede Stadium,
# 10                                 Wankhede Stadium,
# 11                                 Wankhede Stadium,
# 12                                 Wankhede Stadium,
# 13                                 Wankhede Stadium,
# 14                                 Wankhede Stadium,
# 15                                 Wankhede Stadium,
# 16                                 Wankhede Stadium,
# 17     Punjab Cricket Association IS Bindra Stadium,
# 18     Punjab Cricket Association IS Bindra Stadium,
# 19     Punjab Cricket Association IS Bindra Stadium,
# 20     Punjab Cricket Association IS Bindra Stadium,
# 21     Punjab Cricket Association IS Bindra Stadium,
# 22     Punjab Cricket Association IS Bindra Stadium,
# 23     Punjab Cricket Association IS Bindra Stadium,
# 24     Punjab Cricket Association IS Bindra Stadium,
# 25     Punjab Cricket Association IS Bindra Stadium,
# 26     Punjab Cricket Association IS Bindra Stadium,
# 27     Punjab Cricket Association IS Bindra Stadium,
# 28     Punjab Cricket Association IS Bindra Stadium,
# 29     Punjab Cricket Association IS Bindra Stadium,
#                            ...
# 933                                    Eden Gardens,
# 934                                    Eden Gardens,
# 935                                    Eden Gardens,
# 936                                    Eden Gardens,
# 937                                    Eden Gardens,
# 938                                    Eden Gardens,
# 939                                    Eden Gardens,
# 940                                    Eden Gardens,
# 941                                    Eden Gardens,
# 942                                    Eden Gardens,
# 943                                    Eden Gardens,
# 944                                    Eden Gardens,
# 945                                    Eden Gardens,
# 946                                    Eden Gardens,
# 947                                    Eden Gardens,
# 948                                    Eden Gardens,
# 949                                    Eden Gardens,
# 950                                    Eden Gardens,
# 951                                    Eden Gardens,
# 952                                Wankhede Stadium,
# 953                                Wankhede Stadium,
# 954                                Wankhede Stadium,
# 955                                Wankhede Stadium,
# 956                                Wankhede Stadium,
# 957                                Wankhede Stadium,
# 958                                Wankhede Stadium,
# 959                                Wankhede Stadium,
# 960                                Wankhede Stadium,
# 961                                Wankhede Stadium,
# 962                                Wankhede Stadium,
# Name: match_venue, Length: 963, dtype: object

# %%
# aggregations on a data frame
#player_data.count()
#player_data.sum()
#player_data.mean()
#player_data.median()
#player_data.std()
player_data.max()
# Out:
# match_description    Sunrisers Hyderabad vs Royal Challengers Banga...
# match_date                                                  2018-05-27
# match_venue                                          Wankhede Stadium,
# match_location                                                    Pune
# match_result                         Sunrisers Hyderabad won by 9 wkts
# team_name                                  Sunrisers Hyderabad Innings
# innings_order                                                innings_2
# batsman_name                                          Yuzvendra Chahal
# dismissal_mode                          st de Kock b Washington Sundar
# runs                                                               128
# balls                                                               70
# fours                                                                9
# sixes                                                               11
# dtype: object

# %%
x = player_data[['match_description','runs']]
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
y = player_data[player_data['runs']==128]
y
# Out:
#                                      match_description  match_date  \
# 680  Delhi Daredevils vs Sunrisers Hyderabad, 42nd ...  2018-05-10
#
#            match_venue match_location                       match_result  \
# 680  Feroz Shah Kotla,          Delhi  Sunrisers Hyderabad won by 9 wkts
#
#                     team_name innings_order       batsman_name dismissal_mode  \
# 680  Delhi Daredevils Innings     innings_1  Rishabh Pant (wk)        not out
#
#      runs  balls  fours  sixes
# 680   128     63      1      7

# %%
# fetching data
#player_data.loc[2:4]
#player_data.iloc[2:4]
#player_data.loc[2:4,'match_description':'match_location']
#player_data.loc[player_data['runs']>100,'batsman_name']
player_data.iat[2,3]
player_data.head()
# Out:
#                                    match_description  match_date  \
# 0  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 1  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 2  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 3  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 4  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
#
#          match_venue match_location                      match_result  \
# 0  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 1  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 2  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 3  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 4  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
#
#                 team_name innings_order       batsman_name  \
# 0  Mumbai Indians Innings     innings_1   Rohit Sharma (c)
# 1  Mumbai Indians Innings     innings_1         Evin Lewis
# 2  Mumbai Indians Innings     innings_1  Ishan Kishan (wk)
# 3  Mumbai Indians Innings     innings_1   Suryakumar Yadav
# 4  Mumbai Indians Innings     innings_1      Hardik Pandya
#
#          dismissal_mode  runs  balls  fours  sixes
# 0     c Rayudu b Watson    15     18      1      1
# 1        lbw b D Chahar     0      2      0      0
# 2   c Mark Wood b Tahir    40     29      4      1
# 3  c Harbhajan b Watson    43     29      6      1
# 4               not out    22     20      2      0

# %%
# setting data
# player_data.loc[0]
player_data.loc[player_data['runs']>100,'runs'] = 200
# Out:
# 274    104
# 285    106
# 680    128
# 959    117
# Name: runs, dtype: int64

# %%
#creating calculated columns
player_data['str_rate'] = player_data['runs']/player_data['balls']
player_data.head()
# Out:
#                                    match_description  match_date  \
# 0  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 1  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 2  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 3  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 4  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
#
#          match_venue match_location                      match_result  \
# 0  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 1  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 2  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 3  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 4  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
#
#                 team_name innings_order       batsman_name  \
# 0  Mumbai Indians Innings     innings_1   Rohit Sharma (c)
# 1  Mumbai Indians Innings     innings_1         Evin Lewis
# 2  Mumbai Indians Innings     innings_1  Ishan Kishan (wk)
# 3  Mumbai Indians Innings     innings_1   Suryakumar Yadav
# 4  Mumbai Indians Innings     innings_1      Hardik Pandya
#
#          dismissal_mode  runs  balls  fours  sixes  str_rate
# 0     c Rayudu b Watson    15     18      1      1  0.833333
# 1        lbw b D Chahar     0      2      0      0  0.000000
# 2   c Mark Wood b Tahir    40     29      4      1  1.379310
# 3  c Harbhajan b Watson    43     29      6      1  1.482759
# 4               not out    22     20      2      0  1.100000

# %%
# remove columns 
#del player_data['str_rate']
player_data.head()
# Out:
#                                    match_description  match_date  \
# 0  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 1  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 2  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 3  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 4  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
#
#          match_venue match_location                      match_result  \
# 0  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 1  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 2  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 3  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 4  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
#
#                 team_name innings_order       batsman_name  \
# 0  Mumbai Indians Innings     innings_1   Rohit Sharma (c)
# 1  Mumbai Indians Innings     innings_1         Evin Lewis
# 2  Mumbai Indians Innings     innings_1  Ishan Kishan (wk)
# 3  Mumbai Indians Innings     innings_1   Suryakumar Yadav
# 4  Mumbai Indians Innings     innings_1      Hardik Pandya
#
#          dismissal_mode  runs  balls  fours  sixes
# 0     c Rayudu b Watson    15     18      1      1
# 1        lbw b D Chahar     0      2      0      0
# 2   c Mark Wood b Tahir    40     29      4      1
# 3  c Harbhajan b Watson    43     29      6      1
# 4               not out    22     20      2      0

# %%
#working with grouping functions
#grp1 = player_data.groupby(['match_location'])
#grp1.groups
#grp1.get_group('Indore')
#grp1.runs.agg(np.sum)
#grp1.runs.agg(np.median)
#grp1.sixes.agg(np.max)
#grp1.runs.agg(np.std)
#grp1.runs.agg([np.size,np.sum,np.mean,np.median])
#grp1.transform(lambda x:x+5)
# Out:
#      runs  balls  fours  sixes
# 0      20     23      6      6
# 1       5      7      5      5
# 2      45     34      9      6
# 3      48     34     11      6
# 4      27     25      7      5
# 5      46     27     10      7
# 6      21     19      6      6
# 7      27     24      9      5
# 8       9     11      5      5
# 9      29     27      6      7
# 10     10     10      5      5
# 11     17     18      6      5
# 12     73     35      8     12
# 13      5      6      5      5
# 14     13     10      6      5
# 15      6      8      5      5
# 16      7      7      5      5
# 17      9     11      5      5
# 18     60     47     10      6
# 19     16     16      5      6
# 20     18     18      5      5
# 21     33     18      9      6
# 22     14     12      6      5
# 23     32     21      6      6
# 24     18     18      5      6
# 25     56     21     11      9
# 26     12     10      5      6
# 27     17     27      7      5
# 28     55     38     10      7
# 29     29     28      6      5
# ..    ...    ...    ...    ...
# 933    39     29      9      6
# 934     8      8      5      5
# 935    33     29      9      5
# 936    24     24      5      6
# 937     8     12      5      5
# 938    13      9      5      6
# 939    39     15      7      9
# 940    10      7      6      5
# 941    53     36     11      7
# 942    31     18      9      6
# 943    27     21      6      7
# 944     7     13      5      5
# 945    13     11      6      5
# 946    35     25      7      6
# 947     8     12      5      5
# 948    17     17      5      6
# 949    11      9      6      5
# 950     5      8      5      5
# 951     5      5      5      5
# 952    10     10      5      5
# 953    31     30      7      6
# 954    52     41     10      7
# 955    28     20      7      6
# 956    50     30      9      7
# 957     8      9      5      5
# 958    26     16      5      8
# 959   122     62      6     13
# 960    15     16      6      5
# 961    37     29      8      6
# 962    21     24      6      6
#
# [963 rows x 4 columns]

# %%
player_data.groupby(['match_location','batsman_name']).runs.agg(np.std)
# Out:
# match_location  batsman_name
# Bengaluru       AB de Villiers             304
#                 Aaron Finch                  0
#                 Ajinkya Rahane (c)          36
#                 Alex Hales                  37
#                 Ambati Rayudu               82
#                 Andre Russell                0
#                 Andrew Tye                   7
#                 Axar Patel                   2
#                 Ben Cutting                 12
#                 Ben Stokes                  27
#                 Brendon McCullum            79
#                 Chris Lynn                  62
#                 Chris Morris                 0
#                 Chris Woakes                 1
#                 Colin de Grandhomme         85
#                 Corey Anderson              17
#                 D Arcy Short                11
#                 Deepak Hooda                 1
#                 Dinesh Karthik (c & wk)     23
#                 Dwayne Bravo                14
#                 Gautam Gambhir (c)           3
#                 Glenn Maxwell                4
#                 Hardik Pandya               50
#                 Ishan Kishan (wk)            0
#                 Jason Roy                    5
#                 Jean-Paul Duminy            23
#                 Jos Buttler (wk)            23
#                 Kane Williamson (c)         81
#                 Karun Nair                  29
#                 Kieron Pollard              13
#                                           ...
# Pune            Lokesh Rahul (wk)            7
#                 MS Dhoni (c & wk)          149
#                 Mandeep Singh                7
#                 Manish Pandey                5
#                 Manoj Tiwary                35
#                 Mohammed Siraj               3
#                 Mohit Sharma                 2
#                 Murugan Ashwin               1
#                 Parthiv Patel (wk)          53
#                 Prithvi Shaw                 9
#                 Rahul Tewatia                3
#                 Rahul Tripathi               5
#                 Ravichandran Ashwin (c)      0
#                 Ravindra Jadeja              2
#                 Rishabh Pant (wk)           79
#                 Rohit Sharma (c)            56
#                 Sam Billings                 6
#                 Sanju Samson                 2
#                 Shakib Al Hasan              8
#                 Shane Watson               264
#                 Shikhar Dhawan              79
#                 Shreyas Gopal                8
#                 Shreyas Iyer (c)            13
#                 Stuart Binny                10
#                 Suresh Raina               210
#                 Suryakumar Yadav            44
#                 Tim Southee                 36
#                 Umesh Yadav                  1
#                 Vijay Shankar               54
#                 Virat Kohli (c)              8
# Name: runs, Length: 585, dtype: int64

# %%
def run_category(r):
    if r>=100:
        return 'century'
    elif r>=50 and r<100:
        return 'half-century'
    else:
        return 'others'
    
player_data['run_category'] = player_data.runs.map(run_category)
player_data.loc[:,'runs':]
# Out:
#      runs  balls  fours  sixes  run_category
# 0      15     18      1      1        others
# 1       0      2      0      0        others
# 2      40     29      4      1        others
# 3      43     29      6      1        others
# 4      22     20      2      0        others
# 5      41     22      5      2        others
# 6      16     14      1      1        others
# 7      22     19      4      0        others
# 8       4      6      0      0        others
# 9      24     22      1      2        others
# 10      5      5      0      0        others
# 11     12     13      1      0        others
# 12     68     30      3      7  half-century
# 13      0      1      0      0        others
# 14      8      5      1      0        others
# 15      1      3      0      0        others
# 16      2      2      0      0        others
# 17      4      6      0      0        others
# 18     55     42      5      1  half-century
# 19     11     11      0      1        others
# 20     13     13      0      0        others
# 21     28     13      4      1        others
# 22      9      7      1      0        others
# 23     27     16      1      1        others
# 24     13     13      0      1        others
# 25     51     16      6      4  half-century
# 26      7      5      0      1        others
# 27     12     22      2      0        others
# 28     50     33      5      2  half-century
# 29     24     23      1      0        others
# ..    ...    ...    ...    ...           ...
# 933    34     24      4      1        others
# 934     3      3      0      0        others
# 935    28     24      4      0        others
# 936    19     19      0      1        others
# 937     3      7      0      0        others
# 938     8      4      0      1        others
# 939    34     10      2      4        others
# 940     5      2      1      0        others
# 941    48     31      6      2        others
# 942    26     13      4      1        others
# 943    22     16      1      2        others
# 944     2      8      0      0        others
# 945     8      6      1      0        others
# 946    30     20      2      1        others
# 947     3      7      0      0        others
# 948    12     12      0      1        others
# 949     6      4      1      0        others
# 950     0      3      0      0        others
# 951     0      0      0      0        others
# 952     5      5      0      0        others
# 953    26     25      2      1        others
# 954    47     36      5      2        others
# 955    23     15      2      1        others
# 956    45     25      4      2        others
# 957     3      4      0      0        others
# 958    21     11      0      3        others
# 959   117     57      1      8       century
# 960    10     11      1      0        others
# 961    32     24      3      1        others
# 962    16     19      1      1        others
#
# [963 rows x 5 columns]

# %%
player_data['boundaries'] = player_data.apply(lambda x: x['sixes']+x['fours'],axis=1)
player_data.loc[:,'runs':]
# Out:
#      runs  balls  fours  sixes  run_category  boundaries
# 0      15     18      1      1        others           2
# 1       0      2      0      0        others           0
# 2      40     29      4      1        others           5
# 3      43     29      6      1        others           7
# 4      22     20      2      0        others           2
# 5      41     22      5      2        others           7
# 6      16     14      1      1        others           2
# 7      22     19      4      0        others           4
# 8       4      6      0      0        others           0
# 9      24     22      1      2        others           3
# 10      5      5      0      0        others           0
# 11     12     13      1      0        others           1
# 12     68     30      3      7  half-century          10
# 13      0      1      0      0        others           0
# 14      8      5      1      0        others           1
# 15      1      3      0      0        others           0
# 16      2      2      0      0        others           0
# 17      4      6      0      0        others           0
# 18     55     42      5      1  half-century           6
# 19     11     11      0      1        others           1
# 20     13     13      0      0        others           0
# 21     28     13      4      1        others           5
# 22      9      7      1      0        others           1
# 23     27     16      1      1        others           2
# 24     13     13      0      1        others           1
# 25     51     16      6      4  half-century          10
# 26      7      5      0      1        others           1
# 27     12     22      2      0        others           2
# 28     50     33      5      2  half-century           7
# 29     24     23      1      0        others           1
# ..    ...    ...    ...    ...           ...         ...
# 933    34     24      4      1        others           5
# 934     3      3      0      0        others           0
# 935    28     24      4      0        others           4
# 936    19     19      0      1        others           1
# 937     3      7      0      0        others           0
# 938     8      4      0      1        others           1
# 939    34     10      2      4        others           6
# 940     5      2      1      0        others           1
# 941    48     31      6      2        others           8
# 942    26     13      4      1        others           5
# 943    22     16      1      2        others           3
# 944     2      8      0      0        others           0
# 945     8      6      1      0        others           1
# 946    30     20      2      1        others           3
# 947     3      7      0      0        others           0
# 948    12     12      0      1        others           1
# 949     6      4      1      0        others           1
# 950     0      3      0      0        others           0
# 951     0      0      0      0        others           0
# 952     5      5      0      0        others           0
# 953    26     25      2      1        others           3
# 954    47     36      5      2        others           7
# 955    23     15      2      1        others           3
# 956    45     25      4      2        others           6
# 957     3      4      0      0        others           0
# 958    21     11      0      3        others           3
# 959   117     57      1      8       century           9
# 960    10     11      1      0        others           1
# 961    32     24      3      1        others           4
# 962    16     19      1      1        others           2
#
# [963 rows x 6 columns]
