# %%
from sklearn.datasets.samples_generator import make_blobs
import matplotlib.pyplot as plt
import numpy as np

# %%
X,y = make_blobs(n_samples=300,centers=4,cluster_std=0.75,random_state=0)

# %%
X[:5]
# Out:
# array([[ 0.53225417,  2.44603331],
#        [-1.45500868,  7.30316404],
#        [ 1.19994871,  5.29857675],
#        [-0.96120645,  7.80977831],
#        [ 1.07537238,  2.14126167]])

# %%
plt.scatter(X[:,0],X[:,1],s=50)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
y_pred = kmeans.predict(X)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-a8b82e4efdaf> in <module>()
# ----> 1 kmeans.predict([0.532223217,2.4343331].reshape(1,-1))
#
# AttributeError: 'list' object has no attribute 'reshape'

# %%
plt.scatter(X[:,0],X[:,1],c=y_pred,s=50,cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:,0],centers[:,1],c='black',s=200,alpha=0.5)

# %%
centers = kmeans.cluster_centers_

# %%
centers
# Out:
# array([[ 1.96163919,  0.901818  ],
#        [-0.35736037,  3.6442367 ],
#        [-1.40449103,  7.73324588]])

# %%
plt.scatter(centers[:,0],centers[:,1],c='black',s=200,alpha=0.5)
