# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %%
df = pd.read_csv('data/Dataset.csv')
df.head()
#df.columns
cols = df.category_id.unique()
#cols
#df.category_id.unique()
#len(cols)
# Out:
# Index(['date', 'customer_id', 'category_id', 'Transactions',
#        'TransactionValue', 'GR'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(20,20))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1,len(cols)+1):
    plt.subplot(5,3,i)
    plt.scatter(df.loc[df.category_id==cols[i-1]].GR,df.loc[df.category_id==cols[i-1]].TransactionValue)
    plt.title(cols[i-1])
   # plt.plot(data.x,data.y,'.')
   # plt.title('Plot for power:%d'%power)
